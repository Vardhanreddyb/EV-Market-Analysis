# %% [markdown]
# <h1 style="color: red; font-size: 36px; font-family: Arial; font-weight: bold; background-color: lightblue; padding: 10px; border-radius: 10px;" align='center'>PROJECT</h1>

# %% [markdown]
# <h2 style="color: hotpink; font-size: 36px; font-family: Arial; background-color: black; padding: 10px; border-radius: 10px;" align='center'> EV -Market Size Analysis</h2>

# %% [markdown]
# <h2 style="color: #FF0000;">About Dataset :-</h2>
# <h3 style="color: blue;">Context :-</h3>

# %% [markdown]
# Market Size Analysis is the process of estimating the potential sales for a product or service within a particular market segment.
# In the context of electric vehicles (EVs), it involves assessing the total volume of EV registrations to understand the growth of the market,
# forecast future trends, and help stakeholders make informed decisions regarding production, infrastructure development, and policy-making.

# %% [markdown]
# <h2 style="color: Red;">Acknowledgement :-</h2>

# %% [markdown]
# The provided dataset contains the following columns, each representing different aspects of the electric vehicle (EV) population in the United States:
#
# 1. VIN (1-10)             :- Partial Vehicle Identification Number.
# 2. County                 :- The county in which the vehicle is registered.
# 3. City                   :- The city in which the vehicle is registered.
# 4. State                  :- The state in which the vehicle is registered. It appears that this dataset may be focused on Washington (WA) state.
# 5. Postal Code            :- The postal code where the vehicle is registered.
# 6. Model Year             :- The year of the vehicle model.
# 7. Make                   :- The manufacturer of the vehicle.
# 8. Model                  :- The model of the vehicle.
# 9. Electric Vehicle Type  :- The type of electric vehicle, e.g., Battery Electric Vehicle (BEV).
#
# 10. Clean Alternative Fuel Vehicle (CAFV) Eligibility   :- Eligibility status for clean alternative fuel vehicle programs.
# 11. Electric Range         :- The maximum range of the vehicle on a single charge (in miles).
# 12. Base MSRP              :- The Manufacturer’s Suggested Retail Price.
# 13. Legislative District   :- The legislative district where the vehicle is registered.
# 14. DOL Vehicle ID         :- Department of Licensing Vehicle Identification.
# 15. Vehicle Location       :- Geographic coordinates of the vehicle location.
# 16. Electric Utility       :- The electric utility service provider for the vehicle’s location.
# 17. 2020 Census Tract      :- The census tract for the vehicle’s location.

# %% [markdown]
# <h2 style="color: Red;">Objective :-</h2>

# %% [markdown]
# The primary objective of this analysis is to leverage historical EV registration data to understand the current market penetration of EVs, predict future market growth, and identify key trends and factors driving market expansion. The specific goals include:
#
# 1. Assess the historical growth trend of EV registrations.
# 2. Forecast future EV registrations based on historical trends.
# 3. Analyze the distribution of EV registrations across different models, makes, and geographical regions.
# 4. Estimate the market size and growth potential of the EV market for upcoming years.
# 5. Provide insights to support stakeholders in decision-making processes related to production, infrastructure planning, and policy formulation.

# %% [markdown]
# <h2> Loading Required Libraries :- <h2>

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h2> Loading Data :- </h2>

# %%
df = pd.read_csv(r"C:\Users\marup\Downloads\EV-data\Electric_Vehicle_Population_Data.csv")

df
# Out:
#         VIN (1-10)     County           City State  Postal Code  Model Year  \
# 0       5YJYGDEE1L       King        Seattle    WA      98122.0        2020
# 1       7SAYGDEE9P  Snohomish        Bothell    WA      98021.0        2023
# 2       5YJSA1E4XK       King        Seattle    WA      98109.0        2019
# 3       5YJSA1E27G       King       Issaquah    WA      98027.0        2016
# 4       5YJYGDEE5M     Kitsap      Suquamish    WA      98392.0        2021
# ...            ...        ...            ...   ...          ...         ...
# 177861  7SAYGDEE3N     Pierce    Bonney Lake    WA      98391.0        2022
# 177862  KM8K23AG1P      Mason        Shelton    WA      98584.0        2023
# 177863  5YJYGDEE6M      Grant         Quincy    WA      98848.0        2021
# 177864  WVGKMPE27M       King  Black Diamond    WA      98010.0        2021
# 177865  5YJ3E1EA8M     Pierce         Tacoma    WA      98422.0        2021
#
# ...

# %%
## Finding the unique values in tha data.

df.nunique()
# Out:
# VIN (1-10)                                            10830
# County                                                  196
# City                                                    723
# State                                                    46
# Postal Code                                             862
# Model Year                                               22
# Make                                                     40
# Model                                                   139
# Electric Vehicle Type                                     2
# Clean Alternative Fuel Vehicle (CAFV) Eligibility         3
# Electric Range                                          102
# Base MSRP                                                31
# Legislative District                                     49
# DOL Vehicle ID                                       177866
# Vehicle Location                                        861
# Electric Utility                                         76
# ...

# %%
## Descriptive Statistics

df.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  177861.000000  177866.000000   177866.000000  177866.000000
# mean    98172.453506    2020.515512       58.842162    1073.109363
# std      2442.450668       2.989384       91.981298    8358.624956
# min      1545.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2019.000000        0.000000       0.000000
# 50%     98122.000000    2022.000000        0.000000       0.000000
# 75%     98370.000000    2023.000000       75.000000       0.000000
# max     99577.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         177477.000000    1.778660e+05       1.778610e+05
# mean              29.127481    2.202313e+08       5.297672e+10
# std               14.892169    7.584987e+07       1.578047e+09
# min                1.000000    4.385000e+03       1.001020e+09
# ...

# %%
## Infirential Statistics

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177866 entries, 0 to 177865
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         177866 non-null  object
#  1   County                                             177861 non-null  object
#  2   City                                               177861 non-null  object
#  3   State                                              177866 non-null  object
#  4   Postal Code                                        177861 non-null  float64
#  5   Model Year                                         177866 non-null  int64
#  6   Make                                               177866 non-null  object
#  7   Model                                              177866 non-null  object
# ...

# %%
# Head displays top 5 rows (for sample)

df.head()
# Out:
#    VIN (1-10)     County       City State  Postal Code  Model Year   Make  \
# 0  5YJYGDEE1L       King    Seattle    WA      98122.0        2020  TESLA
# 1  7SAYGDEE9P  Snohomish    Bothell    WA      98021.0        2023  TESLA
# 2  5YJSA1E4XK       King    Seattle    WA      98109.0        2019  TESLA
# 3  5YJSA1E27G       King   Issaquah    WA      98027.0        2016  TESLA
# 4  5YJYGDEE5M     Kitsap  Suquamish    WA      98392.0        2021  TESLA
#
#      Model           Electric Vehicle Type  \
# 0  MODEL Y  Battery Electric Vehicle (BEV)
# 1  MODEL Y  Battery Electric Vehicle (BEV)
# 2  MODEL S  Battery Electric Vehicle (BEV)
# 3  MODEL S  Battery Electric Vehicle (BEV)
# 4  MODEL Y  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible             291
# 1  Eligibility unknown as battery range has not b...               0
# ...

# %%
## Shape of the Data set 

## Number of columns and Rows 

print('Shape :- ', df.shape)

print('No of Rows :-', df.shape[0])

print('No of Columns :-', df.shape[1])
# Out:
# Shape :-  (177866, 17)
# No of Rows :- 177866
# No of Columns :- 17

# %%
# Data types of the columns 

df.dtypes
# Out:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                         int64
# Base MSRP                                              int64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# ...

# %%
## List of Columns 

df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %% [markdown]
# These are the list of columns present in the data.

# %%
## Finding the unique values in the dataset 

print(df.nunique())
# Out:
# VIN (1-10)                                            10830
# County                                                  196
# City                                                    723
# State                                                    46
# Postal Code                                             862
# Model Year                                               22
# Make                                                     40
# Model                                                   139
# Electric Vehicle Type                                     2
# Clean Alternative Fuel Vehicle (CAFV) Eligibility         3
# Electric Range                                          102
# Base MSRP                                                31
# Legislative District                                     49
# DOL Vehicle ID                                       177866
# Vehicle Location                                        861
# Electric Utility                                         76
# ...

# %% [markdown]
# We can see the number of unique values present in each columns

# %% [markdown]
# <h1 style="color: Red;">Data Cleaning :-</h1>

# %% [markdown]
# <h3> Handling Null Values :- <h3>

# %%
## Finding the null values in the data.

df.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 5
# City                                                   5
# State                                                  0
# Postal Code                                            5
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 389
# DOL Vehicle ID                                         0
# Vehicle Location                                       9
# Electric Utility                                       5
# ...

# %%
## Percentage of null values.

print(df.isnull().sum() / len(df))
# Out:
# VIN (1-10)                                           0.000000
# County                                               0.000028
# City                                                 0.000028
# State                                                0.000000
# Postal Code                                          0.000028
# Model Year                                           0.000000
# Make                                                 0.000000
# Model                                                0.000000
# Electric Vehicle Type                                0.000000
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0.000000
# Electric Range                                       0.000000
# Base MSRP                                            0.000000
# Legislative District                                 0.002187
# DOL Vehicle ID                                       0.000000
# Vehicle Location                                     0.000051
# ...

# %% [markdown]
# * We can observe that the percentage of null values is low.
# * We can drop  null values. This won't effect the data.

# %%
## Droping the null values 

df.dropna(inplace=True)

# %%
## Checking the null values.

df.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %%
## Converting the the columns data type from float to int .

df[['Postal Code','Legislative District']] = df[['Postal Code','Legislative District']].astype(int)

# %% [markdown]
# <h3> Selecting Relevant Columns <h3>

# %%
df = df[['County', 'City', 'State', 'Postal Code', 'Model Year',
       'Make', 'Model', 'Electric Vehicle Type','Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
       'Base MSRP', 'Legislative District', 'DOL Vehicle ID']]

df.head()
# Out:
#       County       City State  Postal Code  Model Year   Make    Model  \
# 0       King    Seattle    WA        98122        2020  TESLA  MODEL Y
# 1  Snohomish    Bothell    WA        98021        2023  TESLA  MODEL Y
# 2       King    Seattle    WA        98109        2019  TESLA  MODEL S
# 3       King   Issaquah    WA        98027        2016  TESLA  MODEL S
# 4     Kitsap  Suquamish    WA        98392        2021  TESLA  MODEL Y
#
#             Electric Vehicle Type  \
# 0  Battery Electric Vehicle (BEV)
# 1  Battery Electric Vehicle (BEV)
# 2  Battery Electric Vehicle (BEV)
# 3  Battery Electric Vehicle (BEV)
# 4  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible             291
# 1  Eligibility unknown as battery range has not b...               0
# 2            Clean Alternative Fuel Vehicle Eligible             270
# ...

# %% [markdown]
# <h3> Renaming the columns <h3>

# %%
df.columns = ['Country', 'City', 'State', 'Postal Code', 'Model Year',
       'Make', 'Model', 'EV Type','Alternative Fuel Eligibility', 'Vehicle Range',
       'Base Price', 'Registration District', 'License ID']

df.head()
# Out:
#      Country       City State  Postal Code  Model Year   Make    Model  \
# 0       King    Seattle    WA        98122        2020  TESLA  MODEL Y
# 1  Snohomish    Bothell    WA        98021        2023  TESLA  MODEL Y
# 2       King    Seattle    WA        98109        2019  TESLA  MODEL S
# 3       King   Issaquah    WA        98027        2016  TESLA  MODEL S
# 4     Kitsap  Suquamish    WA        98392        2021  TESLA  MODEL Y
#
#                           EV Type  \
# 0  Battery Electric Vehicle (BEV)
# 1  Battery Electric Vehicle (BEV)
# 2  Battery Electric Vehicle (BEV)
# 3  Battery Electric Vehicle (BEV)
# 4  Battery Electric Vehicle (BEV)
#
#                         Alternative Fuel Eligibility  Vehicle Range  \
# 0            Clean Alternative Fuel Vehicle Eligible            291
# 1  Eligibility unknown as battery range has not b...              0
# 2            Clean Alternative Fuel Vehicle Eligible            270
# ...

# %% [markdown]
# <h3> Reconfiguring Data :- <h3>

# %%
df['EV Type'] = df['EV Type'].replace({'Battery Electric Vehicle (BEV)' : 'Battery Vehicle(EV)',
                                      'Plug-in Hybrid Electric Vehicle (PHEV)' : 'Plug-in Hybrid(EV)'})

df['Alternative Fuel Eligibility'] = df['Alternative Fuel Eligibility'].replace({'Eligibility unknown as battery range has not been researched' :'Unknown',
                                        'Clean Alternative Fuel Vehicle Eligible': 'Eligible',                         
                                            'Not eligible due to low battery range' : 'Not Eligible'  })

df.head()
# Out:
#      Country       City State  Postal Code  Model Year   Make    Model  \
# 0       King    Seattle    WA        98122        2020  TESLA  MODEL Y
# 1  Snohomish    Bothell    WA        98021        2023  TESLA  MODEL Y
# 2       King    Seattle    WA        98109        2019  TESLA  MODEL S
# 3       King   Issaquah    WA        98027        2016  TESLA  MODEL S
# 4     Kitsap  Suquamish    WA        98392        2021  TESLA  MODEL Y
#
#                EV Type Alternative Fuel Eligibility  Vehicle Range  \
# 0  Battery Vehicle(EV)                     Eligible            291
# 1  Battery Vehicle(EV)                      Unknown              0
# 2  Battery Vehicle(EV)                     Eligible            270
# 3  Battery Vehicle(EV)                     Eligible            210
# 4  Battery Vehicle(EV)                      Unknown              0
#
#    Base Price  Registration District  License ID
# 0           0                     37   125701579
# ...

# %% [markdown]
#  <h3 style="color: Red; font-size: 36px; font-family: Arial;  padding: 10px; border-radius: 10px;"  >EDA - Exploratory Data Analysis</h3>

# %%
### Top 10 countries with Highest number of EVs registration  

Top_Countries = df['Country'].value_counts().head(10)

print(Top_Countries)


plt.figure(figsize=(14,7)) 
sns.barplot(x=Top_Countries.index, y=Top_Countries.values,palette='coolwarm')
plt.title('Top Countries with Maximum EVs Registration')
plt.ylabel('Total Registrations')
plt.xlabel('Countries')
plt.show()
# Out:
# Country
# King         92740
# Snohomish    21001
# Pierce       13782
# Clark        10409
# Thurston      6428
# Kitsap        5840
# Spokane       4586
# Whatcom       4253
# Benton        2147
# Skagit        1910
# Name: count, dtype: int64

# %% [markdown]
# * 'Kings' country has the higher EV adoption Rate(around 50%-60%) compared to other countries. This shows it has strong market for EV's.
#   Due infrastructure development, high promotions of EV's.
#
# * 'Snohomish', 'Pierce' are in Mid-level adoption rate. This indicates growing acceptace of EV's in these countries. People are getting aware regarding EV'S
#
# * Remaing Countries are  lower adoption areas / emerging markets. May be because of less charging stations, awareness, incentives...etc
#
# * Trends and Patterns:
#      * This shows more developed countries are adopting EV's at a faster rate , may be due to the better access for resources and incentives providing.
#
# *
#
#
# * Conclusion :
#                 Overall some of the potential startegies should be implemented in less adoption areas. They are
#
#    * Invest in charging stations.
#    * Introduce / Enhance Incentives for EV purchase.
#    * Raise awareness about the benefits of EVs, focusing on environmental impact and cost savings..etc. to facilate growth

# %%
## Evs Adoption by the year 

adoption_by_year = df['Model Year'].value_counts().sort_index()

print(adoption_by_year)

plt.figure(figsize=(14,7))
sns.barplot(x=adoption_by_year.index, y=adoption_by_year.values, palette='Accent')
plt.title('EVs Adoption by Time')
plt.xlabel('Mode Year')
plt.ylabel('No.Of Registrations')
plt.show()
# Out:
# Model Year
# 1997        1
# 1998        1
# 1999        5
# 2000        7
# 2002        2
# 2003        1
# 2008       19
# 2010       23
# 2011      775
# 2012     1614
# 2013     4399
# 2014     3496
# 2015     4826
# 2016     5469
# 2017     8534
# 2018    14286
# 2019    10913
# 2020    11740
# 2021    19063
# 2022    27708
# 2023    57519
# 2024     7072
# Name: count, dtype: int64

# %% [markdown]
#  * Initial Growth(1997-2009) :- In the early years, the number of registered electric vehicles was very low. This shows that the market was just starting out, mainly because there was not much infrastructure or awareness about electric vehicles.
#
#  * Rapid Growth (2010-2022): From 2010 to 2022, the number of registered EV's grew quickly, especially after 2011. By 2022, there were 27,708 registrations, indicating that more people are opting for EVs. This growth is likely because of improved technology, more charging stations, and government support for electric vehicles.
#
#  * In the year 2024 it shows a decline to 7,072 registrations, which may indicate either seasonal trends, production issues, or low market. Further investigation is needed to understand this decline.
#
#  * Conclusion :-
# In summary, the data shows that the EV's market is changing quickly and has a lot of growth. This growth is influenced by technology improvements, government regulations, and social factors.For the future changes in the EV market, it's important for stakeholders to keep monitoring trends and plan strategically.

# %%
## Top makers of EVs in the market

top_ev_makers = df['Make'].value_counts()

top_makers = top_ev_makers.head(10)

print(top_makers)

plt.figure(figsize=(14,7))
sns.barplot(y=top_makers.values, x=top_makers.index, palette="cubehelix")
plt.title('Popular EV Makers ')
plt.xlabel('Total Registrations')
plt.ylabel('Top Makers')
plt.show()
# Out:
# Make
# TESLA         79471
# NISSAN        13984
# CHEVROLET     13651
# FORD           9177
# BMW            7556
# KIA            7423
# TOYOTA         6254
# VOLKSWAGEN     4993
# JEEP           4468
# HYUNDAI        4398
# Name: count, dtype: int64

# %% [markdown]
# * "TESLA" is the most sold EV's with 79,471 registrations.  It is a clear market leader. This shows the Tesla's brand recognition, Innovative technology, Wide range of models..etc
#
# * Nissan & Chervolet are the Competitive brands respectively.
#
# * Remaining are the Emerging and Smaller brands
#
# * The data shows many different brands, meaning consumers have lots of options in the electric vehicle market to suit their tastes and budgets.
#
# * The numbers indicate that most brands still have potential to grow their registrations, especially as technology and charging infrastructure get better.
#
# * More people are adopting electric vehicles, also there is a good chance for more growth as more consumers prefering EVs.

# %%
# geographical distribution at county level

ev_county_distribution = df['Country'].value_counts()
top_counties = ev_county_distribution.head(3).index

top_countries_data = df[df['Country'].isin(top_counties)]

ev_city_distribution_top_counties = top_countries_data.groupby(['Country', 'City']).size().sort_values(ascending=False).reset_index(name='Number of Vehicles')

top_cities = ev_city_distribution_top_counties.head(10)
print(top_cities)


plt.figure(figsize=(14, 8))
sns.barplot(x='Number of Vehicles', y='City', hue='Country', data=top_cities, palette="magma")
plt.title('Top Cities in Top Counties by EV Registrations')
plt.xlabel('Number of Vehicles Registered')
plt.ylabel('City')
plt.show()
# Out:
#      Country       City  Number of Vehicles
# 0       King    Seattle               29447
# 1       King   Bellevue                8930
# 2       King    Redmond                6478
# 3       King   Kirkland                5362
# 4       King  Sammamish                5280
# 5       King     Renton                4980
# 6  Snohomish    Bothell                4663
# 7     Pierce     Tacoma                3722
# 8       King    Tukwila                2927
# 9       King       Kent                2782

# %% [markdown]
# Here we can observe the registration of  ev's in cities of top 3 countries.
#
# *  The top 5 cities which has highest EV's registration are located in Kings Country
#
# *  Cities in Snohomish County, such as Kirkland and Sammamish, show moderate EV registrations
#
# *  Both (Snohomish County & Pierce County) showing a decent level of adoption, but still significantly less than cities in King County.
#
# *  Recommendations :-
#    * Invest in more charging stations in lower-adoption areas to encourage EV purchases.
#    * Collaborate with local dealerships to promote electric vehicles.
#    * Local governments sould implement or promote incentives for electric vehicle purchases.

# %%
## top EVs models and their makers

top_models_make = top_makers.head(3).index

models = df[df['Make'].isin(top_models_make)]

top_models_data = models.groupby(['Make', 'Model']).size().sort_values(ascending=False).reset_index(name='Number of Vehicles')

top_models = top_models_data.head(10)

print(top_models)

plt.figure(figsize=(14,7))
sns.barplot(x='Number of Vehicles', y='Model', hue='Make',data=top_models, palette='Set2')
plt.title('Top Models of Top 3 Makes')
plt.xlabel('Number of Vehicles Registered')
plt.ylabel('Model')
plt.show()
# Out:
#         Make     Model  Number of Vehicles
# 0      TESLA   MODEL Y               35921
# 1      TESLA   MODEL 3               30009
# 2     NISSAN      LEAF               13352
# 3      TESLA   MODEL S                7711
# 4  CHEVROLET   BOLT EV                6811
# 5      TESLA   MODEL X                5784
# 6  CHEVROLET      VOLT                4782
# 7  CHEVROLET  BOLT EUV                1770
# 8     NISSAN     ARIYA                 632
# 9  CHEVROLET     SPARK                 240

# %% [markdown]
# *The above graph shows the distribution of electric vehicle registrations among different models from the top 3 manufacturers.
#
# *  These are EV models that most of the customers are  prefered.
#
# *  Tesla's Model-Y and Model-3 are most sold EV's. Around 65% of the market is occupied by Telsa Model's. People has strong preferance for Tesla's offerings, brand loyality, advanced features and ...etc
#
# *  Leaf[Nissan] and Bolt EV[Chervolet]  models are the strong competiotors for the Tesla Models. this models are lower in volume, which may indicate a decline in popularity or a shift in consumer preferences toward more modern electric vehicles.
#
# *  NISSAN’s [ARIYA] and CHEVROLET’s [SPARK] have the least number of registrations among the models shown.
#
# * Recommendations
#    * Increase marketing efforts for less popular models.
#    * Advanced features should be build in the models based on the customer needs.
#    * Analyze the factors contributing to Tesla's dominance, such as brand loyalty, technology, and features, and apply these insights to promote other brands

# %%
top_makes = top_makers.head(5).index

top_makes_ev = df[df['Make'].isin(top_makes)]

top_make_ev_type = top_makes_ev.groupby(['Make','EV Type']).size().sort_values(ascending=False).reset_index(name='EV Type Counts')
                                        

ev_type_make_data = top_make_ev_type

print(ev_type_make_data)

plt.figure(figsize=(12,7))
sns.barplot(hue='EV Type', x='EV Type Counts',y='Make',data=ev_type_make_data,palette='Set3')
plt.title('Top 5 Makes and EV Types')
plt.show()
# Out:
#         Make              EV Type  EV Type Counts
# 0      TESLA  Battery Vehicle(EV)           79471
# 1     NISSAN  Battery Vehicle(EV)           13984
# 2  CHEVROLET  Battery Vehicle(EV)            8869
# 3       FORD  Battery Vehicle(EV)            5509
# 4        BMW   Plug-in Hybrid(EV)            5045
# 5  CHEVROLET   Plug-in Hybrid(EV)            4782
# 6       FORD   Plug-in Hybrid(EV)            3668
# 7        BMW  Battery Vehicle(EV)            2511

# %% [markdown]
# * This shows the top 5 Manufactures and their EV types.
#
# * 'Tesla  & Nissan' are  complete battery vehicles. This companies are manufacturiang only Battery vehicles. This shows the trend towards fully electric vehicles
#
# * Chevrolet, Ford, BMW are the manufactures that offers both the Battery and Plug-in-Hybrid  Electric vehicles.
#
# * This means some consumers  are not  ready to fully commit to battery electric vehicles, as they are fully satisfies with traditional fuel capability vehicles.

# %%
## Adoption  of ev types

ev_type = df['EV Type'].value_counts()

print(ev_type)

print()


plt.figure(figsize=(14,10))

plt.subplot(2,2,1)
plt.pie(df['EV Type'].value_counts(),labels=df['EV Type'].value_counts().index,autopct='%.1f%%',shadow=True, colors=sns.color_palette('Set2'),
       explode=[0.1,0], pctdistance=0.80,)
hole = plt.Circle((0, 0), 0.65, facecolor='white')
plt.gcf().gca().add_artist(hole)
plt.title("Adoption of EVs Type")


plt.subplot(2,2,2)
sns.countplot(x=df['EV Type'],palette='viridis')
plt.title('Count of EV Type')

plt.tight_layout()
plt.show()
# Out:
# EV Type
# Battery Vehicle(EV)    138947
# Plug-in Hybrid(EV)      38526
# Name: count, dtype: int64

# %% [markdown]
# * The Battery Vehicle[EV] adoption rate is high with 1.38 lakh +  registrations [around 79% market] is occupied.
#
# * Plug-in-Hybrid[EV] vehicles has lower adoption percentage with 21% only. This EV type vehicles has less market in EV's  segment.
#
# * This indicates that consumer preferences may continue to shift away from hybrids toward fully electric options.

# %%
## Alternative fuel eligibility 

alternative_fuel = df['Alternative Fuel Eligibility'].value_counts()

print(alternative_fuel)

print()


plt.figure(figsize=(14,10))


plt.subplot(2,2,1)
plt.pie(df['Alternative Fuel Eligibility'].value_counts(),labels=df['Alternative Fuel Eligibility'].value_counts().index,autopct='%.1f%%',shadow=True, 
        colors=sns.color_palette('Accent'),explode=[0,0,0.2])

plt.title("Alternative Fuel Eligibility")

colors=['#A890F0','#a9f971','#fdaa48']
plt.subplot(2,2,2)
sns.countplot(x=df['Alternative Fuel Eligibility'],palette=colors)
plt.title('Count of Alternative Fuel Count')

plt.tight_layout()
plt.show()
# Out:
# Alternative Fuel Eligibility
# Unknown         91790
# Eligible        66166
# Not Eligible    19517
# Name: count, dtype: int64

# %% [markdown]
# * A significant portion of vehicles 91,790 [around 52%] have "Unknown" eligibility status. This may be because of battery range has not been researched.
#
# * There are more 'Eligible' vehicles compared to those that are 'Not Eligible" (approximately 3.4 times more). This is a positive outlook for EV adoption, as some number is meet the criteria for Alternative fuel incentives.
#
# * The 'Not Eligible'  status vehicles are  11%  in market. may be due to the low battery range.

# %%
## distribution of vehicles range 
print('Average Vehicle Range :-',df['Vehicle Range'].mean())


plt.figure(figsize=(14,7))
sns.histplot(x=df['Vehicle Range'],  bins=30, kde=True, color='green')
plt.title('Distribution of Electric Vehicle Ranges')
plt.axvline(df['Vehicle Range'].mean(), color='red', linestyle='--', label=f'Mean Range: {df["Vehicle Range"].mean():.2f} miles')
plt.xlabel('Electric Range in miles')
plt.ylabel('Number of Vehicles')
plt.show()
# Out:
# Average Vehicle Range :- 58.82654826367955

# %% [markdown]
# * This Graph describes the distribution of Electric Vehicle Range[  average range that  vehicles can travel in miles]
#
# * We can observe There is a high frequency of vehicles with lower  electric range, and a significant peak before the 50 miles range.
#
# * The distribution is right skewed, with a long line extending towards higher ranges, although the number of vehicles with higher ranges are much less frequent.
#
# * The Average electric range of vehicles is marked at approximately 58.84 miles, which is relatively low thgan the highest ranges shown in the graph.
#
# * We can see the  vehicles electric range is extended up to 350 miles, but the majority of the vehilces range is below the average.

# %%
## year wise trend analysis

average_range_modelyear = df.groupby('Model Year')['Vehicle Range'].mean().reset_index()

print(average_range_modelyear)

plt.figure(figsize=(14,7))
sns.lineplot(x='Model Year', y='Vehicle Range', data=average_range_modelyear, marker='o')
plt.grid(True)
plt.title('Average Range of Vehicles Based on The Model Year')
plt.ylabel('Vehicle Range [Miles]')
# Out:
#     Model Year  Vehicle Range
# 0         1997      39.000000
# 1         1998      58.000000
# 2         1999      74.000000
# 3         2000      58.000000
# 4         2002      95.000000
# 5         2003      95.000000
# 6         2008     220.000000
# 7         2010     226.086957
# 8         2011      70.891613
# 9         2012      61.172243
# 10        2013      79.822232
# 11        2014      80.798341
# 12        2015      98.254869
# 13        2016     101.197111
# 14        2017     114.162292
# 15        2018     156.165967
# 16        2019     176.918904
# 17        2020     238.748978
# 18        2021      11.402665
# 19        2022       4.518045
# 20        2023       3.729168
# 21        2024      16.791431
# Text(0, 0.5, 'Vehicle Range [Miles]')

# %% [markdown]
# This graph shows the Progression of  average electric range of the vehicles from the year 1997 ttto 2024.
#
# * There is a clear upward trend in the  average electric range of EVs over the years, This shows the improvement in terms technology and battery efficiency of the EV vehiles.
#
# * From the year 2003 there is a significant growth in the electric range of vehicles till the year 2010, with highest range of 226 miles in 2010 models vehicles.
#
# * There is a  decline in between the year 2010 and 2020. From the year 2011 to 2015 and the average  electric range is dropped to 98.2.
#
# * The most notable growth is  occurred in 2020 model, where the range reached 238.75 miles.
#
# * After 2020, the data shows a sharp decline in electric range of vehicles i.e dropped to 3.72 and the growth is started increasing 2024 with a range of 16.7 average.

# %%
## Relation ship between price and range of Ev's

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Vehicle Range', y='Base Price', hue='EV Type')
plt.title('Electric Range vs Base MSRP')
plt.xlabel('Electric Range')
plt.ylabel('Base MSRP')
plt.legend(title='EV Type')
plt.show()

# %% [markdown]
# * The above graph describes the relation ship between the Base price and Electric range of the EV Vehicles based on their EV Type.
#
# * We can observe that most of the vehicles base price is below 20,000  only only one is above the 80,000 base price and the range is below 50 miles .
#
# * Most of the  plug-in-hybrid vehiles are in between 0 to 50 miles range.

# %%
## Top models,their make and the average rangle of the vehicles

average_range_by_model = models.groupby(['Make', 'Model'])['Vehicle Range'].mean().sort_values(ascending=False).reset_index()


top_range_models = average_range_by_model.head(10)

print(top_range_models)

plt.figure(figsize=(14, 7))
barplot = sns.barplot(x='Vehicle Range', y='Model', hue='Make', data=top_range_models, palette="coolwarm")
plt.title('Top 10 Models by Average Electric Range in Top Makes')
plt.xlabel('Average Electric Range (miles)')
plt.ylabel('Model')
plt.legend(title='Make', loc='center right')
plt.show()
# Out:
#         Make        Model  Vehicle Range
# 0      TESLA     ROADSTER     234.673913
# 1      TESLA      MODEL S     176.794449
# 2  CHEVROLET      BOLT EV     154.857143
# 3      TESLA      MODEL X     137.192600
# 4      TESLA      MODEL 3     109.463028
# 5     NISSAN         LEAF      84.148742
# 6  CHEVROLET        SPARK      82.000000
# 7  CHEVROLET         VOLT      45.365119
# 8  CHEVROLET  S-10 PICKUP      39.000000
# 9      TESLA      MODEL Y      19.191531

# %% [markdown]
# * The above graph shows the distribution of electric range  among different models from the top three manufacturers.
#
# * Tesla's models occupied top positions surpassing all other models.
#
# * Tesla's Roadster & Model-s Models are placed in top 2 with highest range of 234.7 and 176.8 miles.
#
# * The Chevrolet Bolt EV ranks third with a range of 154.86 miles, demonstrating that other manufacturers can compete with Tesla in terms of range
#
# * The Chevrolet Spark (82 miles), Volt (45.37 miles), and S-10 Pickup (39 miles), and aslo  the Nissan Leaf (84.15 miles), These models have shorter ranges. These models may be suited for city driving or shorter distances.
#
# * This  suggests that consumers looking for long-range electric vehicles . As electric vehicle adoption increases, consumers may prioritize longer range vehicles, particularly for those who need to travel longer distances without frequent charging stations

# %%
corelation_matrix = df[['Model Year','Vehicle Range','Base Price']].corr()

print(corelation_matrix)


print()


plt.figure(figsize=(12, 7))
sns.heatmap(corelation_matrix,annot=True, linewidths=0.5,cmap='crest')
plt.title("Co-relation Matrix")
plt.show()
# Out:
#                Model Year  Vehicle Range  Base Price
# Model Year       1.000000      -0.477031   -0.230176
# Vehicle Range   -0.477031       1.000000    0.108246
# Base Price      -0.230176       0.108246    1.000000

# %% [markdown]
# * The correlation  of -0.477 means a moderate negative relationship. This indicates that as the model year increases , the vehicle range tends to decrease.
#
# * The correlation of 0.108 suggests a very weak positive relationship between vehicle range and base price.
#
# * The correlation of -0.230 indicates a weak negative relationship between model year and base price.

# %% [markdown]
# <h2> CONCLUSION :- <h2>
#
# This analysis shows that there is strong potential for electric vehicle (EV) adoption in the USA. Overall, the data indicates a positive trend in the growth of the EV market.
#
# We can conclude that the size of the EV market is expected to grow significantly. The increase in vehicle registrations suggests that more consumers are choosing E over the fuel vehiclesVs, and this trend is likely to continue. From my analysis of the EV market size, I found that the industry has a bright future ahead.
